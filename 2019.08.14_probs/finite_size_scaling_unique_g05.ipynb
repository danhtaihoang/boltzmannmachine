# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.loadtxt('Z_unique_g05.txt').T

# %%
z0 = 15.203385326641719

# %%
plt.plot(z[0],z[1],'ko-')
plt.plot([z[0].min(),z[0].max()],[z0,z0],'r--')

# %%
plt.plot(1/np.log(z[0]),z[1],'ko-')
plt.plot([0,1/np.log(z[0].min())],[z0,z0],'r--')
plt.xlim([1/np.log(2**20),1/np.log(z[0].min())])
# Out:
# (0.07213475204444816, 0.10857362047581294)
